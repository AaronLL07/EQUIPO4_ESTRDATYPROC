# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronLL07/EQUIPO4_ESTRDATYPROC/blob/main/Ev2_Dataframe_GoogleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2bc4c245-01a5-42e1-bc48-c9bcfd04f964" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bc4c245-01a5-42e1-bc48-c9bcfd04f964">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'ev2lista.csv': b'\xef\xbb\xbf,CANTIDAD,DESCRIPCION,PRECIO UNITARIO,IMPORTE, DESCUENTO ,TOTAL CON DECUENTO,FECHA DE ENTRADA,DEPARTAMENTO,BANCO,NUMERO DE PRODUCTO\r\n0, 3 ,Bol\xc3\xadgrafo Bic Cristal Punto Ultrafino Negro\xc2\xa0,7.30,21.90,30%, $15.33 ,"martes, 3 de enero de 2023",Escolar y Papeler\xc3\xada,SANTANDER,25018\r\n1, 1 ,Cuaderno College Norma Color Cosido Cuadro Chico 100 Hojas,76.90,76.90,30%, $53.83 ,"jueves, 2 de marzo de 2023",Escolar y Papeler\xc3\xada,SANTANDER,24799\r\n2, 1 ,"Pantalla TCL Smart 32"" HD Smart TV",4799.90,4799.90,0%," $4,799.90 ","mi\xc3\xa9rcoles, 15 de marzo de 2023",Electr\xc3\xb3nica,SANTANDER,24734\r\n3, 1 ,Camara Web Acteck 720P WM20 Negro,319.90,319.90,50%, $159.95 ,"viernes, 7 de abril de 2023",Electr\xc3\xb3nica,BANORTE,24730\r\n4, 1 ,Mouse Gaming Inal\xc3\xa1mbrico Hiperion Balam Rush Espectrum,749.00,749.00,0%, $749.00 ,"martes, 11 de abril de 2023",Electr\xc3\xb3nica,BANORTE,24767\r\n5, 1 ,Tinte para Cabello Tono Vainilla 100% Cobertura
# ...

# %%
dataframe = pd.read_csv(io.StringIO(uploaded['ev2lista.csv'].decode('utf-8')))

# %%
dataframe.head()
# Out:
#    Unnamed: 0  CANTIDAD                                        DESCRIPCION  \
# 0         0.0       3.0       Bolígrafo Bic Cristal Punto Ultrafino Negro
# 1         1.0       1.0  Cuaderno College Norma Color Cosido Cuadro Chi...
# 2         2.0       1.0                 Pantalla TCL Smart 32" HD Smart TV
# 3         3.0       1.0                  Camara Web Acteck 720P WM20 Negro
# 4         4.0       1.0  Mouse Gaming Inalámbrico Hiperion Balam Rush E...
#
#    PRECIO UNITARIO  IMPORTE  DESCUENTO  TOTAL CON DECUENTO  \
# 0              7.3     21.9         30%            $15.33
# 1             76.9     76.9         30%            $53.83
# 2           4799.9   4799.9          0%         $4,799.90
# 3            319.9    319.9         50%           $159.95
# 4            749.0    749.0          0%           $749.00
#
#                  FECHA DE ENTRADA         DEPARTAMENTO      BANCO  \
# 0      martes, 3 de enero de 2023  Escolar y Papelería  SANTANDER
# ...
